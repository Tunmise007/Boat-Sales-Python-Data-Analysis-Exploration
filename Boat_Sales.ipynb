# %% [markdown]
# ## **Introductions**
# Handsworth Boats is a specialised organisation that deals with the sale of yachts and boats. The marketing team is currently in the process of creating a weekly newsletter aimed at assisting boat owners in increasing views of their boats and staying up to date with market trends. The team intends to analyse recent data to gain valuable insights. Some potential inquiries that the team could explore are as follows:
# 1.	What are the distinguishing features of the most frequently viewed boat listings in the past 7 days?
# 2.	Do the most expensive boats receive the highest number of views?
# 3.	Are there shared characteristics among the most viewed boats?

# %% [markdown]
# ### **Dataset**
#
# Column Name	 --  Details
#
# *   Price - Character, boat price listed in different currencies (e.g.EUR, Â£, CHF etc.) on the website
#
# *   Boat Type -  Character, type of the boat
#
# *   Manufacturer - Character, manufacturer of the boat
#
# *   Type - Character, condition of the boat and engine type(e.g. Diesel, Unleaded, etc.)
#
# *   Year - Built Numeric, year of the boat built
#
# *   Length - Numeric, length in meter of the boat
#
# *   Width - Numeric, width in meter of the boat
#
# *   Material- Character, material of the boat (e.g. GRP, PVC, etc.)
#
# *   Location - Character, location of the boat is listed
#
# *   Number of views last 7 days - Numeric, number of the views of the list last 7 days

# %% [markdown]
# ### **Required Libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %% [markdown]
# **Load Data**

# %%
#reading boat sales data from google drive
boat_sales = pd.read_csv('/content/drive/MyDrive/boat_data.csv')

boat_sales.head()
# Out:
#        Price            Boat Type          Manufacturer                 Type  \
# 0   CHF 3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   EUR 3490  Center console boat     Terhi power boats  new boat from stock
# 2   CHF 3770           Sport Boat    Marine power boats  new boat from stock
# 3  DKK 25900           Sport Boat    Pioner power boats  new boat from stock
# 4   EUR 3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58

# %% [markdown]
# ## **Data understanding**

# %%
shape = boat_sales.shape

print('Rows :', shape[0])
print('Columns :', shape[1])
# Out:
# Rows : 9888
# Columns : 10

# %%
#inspecting data
boat_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        9888 non-null   object
#  1   Boat Type                    9888 non-null   object
#  2   Manufacturer                 8550 non-null   object
#  3   Type                         9882 non-null   object
#  4   Year Built                   9888 non-null   int64
#  5   Length                       9879 non-null   float64
#  6   Width                        9832 non-null   float64
#  7   Material                     8139 non-null   object
#  8   Location                     9852 non-null   object
#  9   Number of views last 7 days  9888 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 772.6+ KB

# %% [markdown]
# *   Data has null values
# *   Wrong data types
#
# *   Location & Price column values need to be standardised

# %% [markdown]
# # **Data Cleaning**

# %%
#Defining a function to normailse the 'Price' column to have currency
def currency(x):
  column1 = x.split(" ")[0]
  return column1

def price(x):
  column_2 = x.split(" ")[1]
  return column_2

# %%
#Applying the functions 
boat_sales['Currency'] = boat_sales['Price'].apply(currency)

boat_sales['Price'] = boat_sales['Price'].apply(price)

# %%
boat_sales.head()
# Out:
#    Price            Boat Type          Manufacturer                 Type  \
# 0   3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   3490  Center console boat     Terhi power boats  new boat from stock
# 2   3770           Sport Boat    Marine power boats  new boat from stock
# 3  25900           Sport Boat    Pioner power boats  new boat from stock
# 4   3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#   Currency
# 0      CHF
# 1      EUR
# 2      CHF
# 3      DKK
# 4      EUR

# %%
#Replacing Â£ to GBP
boat_sales['Currency'] = boat_sales['Currency'].replace('Â£', 'GBP')

# %%
boat_sales['Currency'].value_counts()
# Out:
# EUR    8430
# CHF     980
# GBP     298
# DKK     180
# Name: Currency, dtype: int64

# %%
#Convering price to GBP (FX Rate as at 2023-04-30)
def change_price (Price, Currency):
  if Currency == 'EUR':
    return int(Price) * 0.87
  elif Currency == 'CHF':
    return int(Price) * 0.89
  elif Currency == 'GBP':
    return Price
  elif Currency == 'DKK':
    return int(Price) * 0.11

# %%
boat_sales['GBP Price'] = boat_sales.apply(lambda x: change_price(x.Price, x.Currency), axis=1)

# %%
boat_sales.head()
# Out:
#    Price            Boat Type          Manufacturer                 Type  \
# 0   3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   3490  Center console boat     Terhi power boats  new boat from stock
# 2   3770           Sport Boat    Marine power boats  new boat from stock
# 3  25900           Sport Boat    Pioner power boats  new boat from stock
# 4   3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#   Currency GBP Price
# 0      CHF   2969.93
# 1      EUR    3036.3
# 2      CHF    3355.3
# 3      DKK    2849.0
# 4      EUR   2957.13

# %% [markdown]
# **Standardising columns**

# %%
#Split location into country and city
boat_sales[['Country', 'City']] = boat_sales['Location'].str.split('Â»', 1, expand=True)

boat_sales[['City', 'Other']] = boat_sales['City'].str.split('Â»', 1, expand=True)

boat_sales['City'] = boat_sales['City'].str.replace('¶', '')

boat_sales['City'] = boat_sales['City'].str.replace('Ã', '')


boat_sales.head()
# Out:
# <ipython-input-13-777afc08bc21>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   boat_sales[['Country', 'City']] = boat_sales['Location'].str.split('Â»', 1, expand=True)
# <ipython-input-13-777afc08bc21>:4: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   boat_sales[['City', 'Other']] = boat_sales['City'].str.split('Â»', 1, expand=True)
#    Price            Boat Type          Manufacturer                 Type  \
# 0   3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   3490  Center console boat     Terhi power boats  new boat from stock
# 2   3770           Sport Boat    Marine power boats  new boat from stock
# 3  25900           Sport Boat    Pioner power boats  new boat from stock
# 4   3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#   Currency GBP Price       Country              City       Other
# 0      CHF   2969.93  Switzerland       Lake Geneva     VÃ©senaz
# 1      EUR    3036.3      Germany        Bnningstedt        None
# 2      CHF    3355.3  Switzerland    Lake of Zurich    StÃ¤fa ZH
# 3      DKK    2849.0      Denmark          Svendborg        None
# 4      EUR   2957.13      Germany            Bayern     MÃ¼nchen

# %% [markdown]
# **Fill NaN values**

# %%
boat_sales.isna().sum()
# Out:
# Price                             0
# Boat Type                         0
# Manufacturer                   1338
# Type                              6
# Year Built                        0
# Length                            9
# Width                            56
# Material                       1749
# Location                         36
# Number of views last 7 days       0
# Currency                          0
# GBP Price                         0
# Country                          36
# City                            943
# Other                          6690
# dtype: int64

# %%
boat_sales['Manufacturer'].value_counts()
# Out:
# BÃ©nÃ©teau power boats         631
# Jeanneau power boats           537
# Sunseeker power boats          383
# Princess power boats           241
# Sea Ray power boats            239
#                               ...
# Aegean Yachts power boats        1
# ISA Yachts power boats           1
# Couach power boats               1
# Perini Navi Spa power boats      1
# Hunter power boats               1
# Name: Manufacturer, Length: 910, dtype: int64

# %%
#Fill NaN Values
boat_sales['Manufacturer'].fillna('None', inplace=True)       
boat_sales['Country'].fillna('None', inplace=True)  
boat_sales['City'].fillna('None', inplace=True)  
boat_sales['Type'].fillna(boat_sales['Type'].value_counts().idxmax(), inplace=True)
boat_sales['Length'].fillna(boat_sales['Length'].median(), inplace=True)
boat_sales['Width'].fillna(boat_sales['Width'].median(), inplace=True)
boat_sales['Material'].fillna(boat_sales['Material'].value_counts().idxmax(), inplace=True)

# %% [markdown]
# **Drop unwanted columns**

# %%
boat_sales_clean = boat_sales.drop(['Location', 'Price', 'Other'], axis=1)

# %% [markdown]
# **Changing Data Types**

# %%
print(boat_sales_clean.dtypes)
# Out:
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                       int64
# Length                         float64
# Width                          float64
# Material                        object
# Number of views last 7 days      int64
# Currency                        object
# GBP Price                       object
# Country                         object
# City                            object
# dtype: object

# %%
#soft-conversion by inferring the data type of ‘object’-type columns. Non-object and unconvertible columns are left unchanged
boat_sales_clean = boat_sales_clean.infer_objects()

# %%
#Changing 'GBP Price' to int
boat_sales_clean['GBP Price'] = boat_sales_clean[['GBP Price']].apply(pd.to_numeric)

# %%
print(boat_sales_clean.dtypes)
# Out:
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                       int64
# Length                         float64
# Width                          float64
# Material                        object
# Number of views last 7 days      int64
# Currency                        object
# GBP Price                      float64
# Country                         object
# City                            object
# dtype: object

# %%
boat_sales_clean.head()
# Out:
#              Boat Type          Manufacturer                 Type  Year Built  \
# 0          Motor Yacht  Rigiflex power boats  new boat from stock        2017
# 1  Center console boat     Terhi power boats  new boat from stock        2020
# 2           Sport Boat    Marine power boats  new boat from stock           0
# 3           Sport Boat    Pioner power boats  new boat from stock        2020
# 4         Fishing Boat    Linder power boats  new boat from stock        2019
#
#    Length  Width       Material  Number of views last 7 days Currency  \
# 0    4.00   1.90            GRP                          226      CHF
# 1    4.00   1.50  Thermoplastic                           75      EUR
# 2    3.69   1.42      Aluminium                          124      CHF
# 3    3.00   1.00            GRP                           64      DKK
# 4    3.55   1.46      Aluminium                           58      EUR
#
#    GBP Price       Country              City
# 0    2969.93  Switzerland       Lake Geneva
# 1    3036.30      Germany        Bnningstedt
# 2    3355.30  Switzerland    Lake of Zurich
# 3    2849.00      Denmark          Svendborg
# 4    2957.13      Germany            Bayern

# %%
boat_sales_clean[['Boat Type', 'Other Type']] = boat_sales_clean['Boat Type'].str.split(',', 1, expand=True)
# Out:
# <ipython-input-23-9d459fe4b577>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   boat_sales_clean[['Boat Type', 'Other Type']] = boat_sales_clean['Boat Type'].str.split(',', 1, expand=True)

# %%
boat_sales_clean.head()
# Out:
#              Boat Type          Manufacturer                 Type  Year Built  \
# 0          Motor Yacht  Rigiflex power boats  new boat from stock        2017
# 1  Center console boat     Terhi power boats  new boat from stock        2020
# 2           Sport Boat    Marine power boats  new boat from stock           0
# 3           Sport Boat    Pioner power boats  new boat from stock        2020
# 4         Fishing Boat    Linder power boats  new boat from stock        2019
#
#    Length  Width       Material  Number of views last 7 days Currency  \
# 0    4.00   1.90            GRP                          226      CHF
# 1    4.00   1.50  Thermoplastic                           75      EUR
# 2    3.69   1.42      Aluminium                          124      CHF
# 3    3.00   1.00            GRP                           64      DKK
# 4    3.55   1.46      Aluminium                           58      EUR
#
#    GBP Price       Country              City Other Type
# 0    2969.93  Switzerland       Lake Geneva        None
# 1    3036.30      Germany        Bnningstedt       None
# 2    3355.30  Switzerland    Lake of Zurich        None
# 3    2849.00      Denmark          Svendborg       None
# 4    2957.13      Germany            Bayern        None

# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# **What are the distinguishing features of the most frequently viewed boat listings in the past 7 days?**

# %%
boat_type_views2 = boat_sales_clean.pivot_table(values ='Number of views last 7 days',
                                                index='Boat Type',
                                                aggfunc= np.sum).sort_values('Number of views last 7 days')

boat_type_views2.reset_index(inplace=True)

# %%
fig = px.bar(boat_type_views2, x='Boat Type', y='Number of views last 7 days', color_discrete_sequence = ["gray"], title='Most Viewed Boat Type In The Last 7 Days') 

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c807ca7b-5ac3-4f7c-85b7-44d217304a55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c807ca7b-5ac3-4f7c-85b7-44d217304a55")) {                    Plotly.newPlot(                        "c807ca7b-5ac3-4f7c-85b7-44d217304a55",                        [{"alignmentgroup":"True","hovertemplate":"Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"","marker":{"color":"gray","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RIB","Ketch","Motorsailer","Water ski","Catamaran","Passenger boat","Working Boat","Launch","Offshore Boat","Pontoon Boat","Runabout","Mega Yacht","Wakeboard/Wakesurf","House Boat","Deck Boat","Fishing Boat","Center console boat","Classic","Bowrider","Hardtop","Pilothouse","Trawler","Flybridge","Cabin Boat","Sport Boat","Motor Yacht"],"xaxis":"x","y":[43,97,287,2979,4304,4503,6313,6476,12868,15122,15444,20128,22407,26185,30684,34296,38722,51510,53258,69669,74997,75456,130350,162762,257024,359018],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar ...

# %%
boat_type_pivot = boat_sales_clean.pivot_table(values =['Number of views last 7 days'],
                                                index=['Boat Type', 'Material'],
                                                aggfunc= np.sum)

boat_type_pivot.reset_index(inplace=True)

boat_type_pivot.head()

# %%
fig = px.bar(boat_type_pivot, x='Boat Type', y='Number of views last 7 days', title='Most Viewed Boat Type & Material In The Last 7 Days', color = 'Material') 


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d9da5cc0-0f09-40d5-a227-9719d65793dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9da5cc0-0f09-40d5-a227-9719d65793dd")) {                    Plotly.newPlot(                        "d9da5cc0-0f09-40d5-a227-9719d65793dd",                        [{"alignmentgroup":"True","hovertemplate":"Material=Aluminium<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"Aluminium","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Aluminium","offsetgroup":"Aluminium","orientation":"v","showlegend":true,"textposition":"auto","x":["Bowrider","Cabin Boat","Catamaran","Center console boat","Classic","Deck Boat","Fishing Boat","Flybridge","Hardtop","House Boat","Launch","Mega Yacht","Motor Yacht","Offshore Boat","Passenger boat","Pilothouse","Pontoon Boat","Runabout","Sport Boat","Trawler","Wakeboard/Wakesurf","Working Boat"],"xaxis":"x","y":[2152,1609,851,898,256,2055,6369,522,170,3403,137,3509,2456,282,421,1104,1384,514,7794,263,690,1977],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Material=Carbon Fiber<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"Carbon Fiber","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Carbon Fiber","offsetgroup":"Carbon Fiber","orientation":"v","showlegend":true,"textposition":"auto","x":["Bowrider","Cabin Boat","Center console boat","Deck Boat","Flybridge","Motor Yacht","Offshore Boat","Runabout","Sport Boat","Wakeboard/Wakesurf"],"xaxis":"x","y":[628,1945,39,51,183,1472,590,57,2772,216],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Material=GRP<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"GRP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"GRP","offsetgroup":"GRP","orientation":"v","showlegend":true,"textposition":"auto","x":["Bowrider","Cabin Boat","Catamaran","Center console boat","Classic","Deck Boat","Fishing Boat","Flybridge","Hardtop","House Boat","Launch","Mega Yacht","Motor Yacht","Offshore Boat","Passenger boat","Pilothouse","Pontoon Boat","RIB","Runabout","Sport Boat","Trawler","Wakeboard/Wakesurf","Water ski","Working Boat"],"xaxis":"x","y":[46419,130067,3057,28181,12681,22038,24170,109680,58477,9099,4466,14253,304237,11293,1003,54162,13055,43,11388,211721,16310,19915,2979,1991],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Material=PVC<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"PVC","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PVC","offsetgroup":"PVC","orientation":"v","showlegend":true,"textposition":"auto","x":["Bowrider","Cabin Boat","Catamaran","Center console boat","Deck Boat","Fishing Boat","Flybridge","Hardtop","House Boat","Ketch","Motor Yacht","Passenger boat","Pilothouse","Sport Boat","Trawler","Wakeboard/Wakesurf"],"xaxis":"x","y":[3363,2125,85,7984,5405,179,15800,9136,113,97,10551,144,18628,17617,4447,294],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Material=Thermoplastic<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"Thermoplastic","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Thermoplastic","offsetgroup":"Thermoplastic","orientation":"v","showlegend":true,"textposition":"auto","x":["Bowrider","Center console boat","Deck Boat","Fishing Boat","Launch","Motor Yacht","Sport Boat"],"xaxis":"x","y":[609,75,373,1369,222,331,721],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Material=Wood<br>Boat Type=%{x}<br>Number of views last 7 days=%{y}<extra></extra>","legendgroup":"Wood","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Wood ...

# %% [markdown]
# **Do the most expensive boats receive the highest number of views?**

# %%
#Grouping the data by Boat Type and summing the values
boat_type_group = boat_sales_clean.groupby(['Boat Type'], as_index=False).sum()

# Assigning the values to a new variable
Boat_type = boat_type_group["Boat Type"].values
GBP_Price = boat_type_group["GBP Price"].values
Views = boat_type_group["Number of views last 7 days"].values

# Creating a bar chart with the x-axis as the month and the y-axis as the total sales.
fig = go.Figure(
    data=go.Bar(
        x=Boat_type,
        y=GBP_Price,
        name="Price of Boats",
        marker=dict(color="gray"),
    )
)
# Adding a second y-axis to the chart.
fig.add_trace(
    go.Scatter(
        x=Boat_type,
        y=Views,
        yaxis="y2",
        name="Views",
        marker=dict(color="orange"),
    )
)
# Updating the layout of the figure.
fig.update_layout(
    title = 'Do the most expensive boats have more views',
    legend=dict(orientation="h"),
    yaxis=dict(
        title=dict(text="Price of Boats"),
        side="left",
    ),
    yaxis2=dict(
        title=dict(text="No of Views in the last 7 days"),
        side="right",
        overlaying="y",
        tickmode="auto",
    ),
)

fig.show()
# Out:
# <ipython-input-42-827ca61ee0ac>:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="54f5e7ae-fb23-414c-a28b-74d391db04e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54f5e7ae-fb23-414c-a28b-74d391db04e8")) {                    Plotly.newPlot(                        "54f5e7ae-fb23-414c-a28b-74d391db04e8",                        [{"marker":{"color":"gray"},"name":"Price of Boats","x":["Bowrider","Cabin Boat","Catamaran","Center console boat","Classic","Deck Boat","Fishing Boat","Flybridge","Hardtop","House Boat","Ketch","Launch","Mega Yacht","Motor Yacht","Motorsailer","Offshore Boat","Passenger boat","Pilothouse","Pontoon Boat","RIB","Runabout","Sport Boat","Trawler","Wakeboard/Wakesurf","Water ski","Working Boat"],"y":[15439628.89,36620564.92,16172077.43,26023676.32,16912990.07,12120362.4,6756852.56,506385187.48,158020471.28,19482211.16,91350.0,1462816.15,541524409.0,963375379.44,1539891.3,5477400.03,12570179.7,36187538.49,3314031.48,9889.0,6096457.67,95943003.79,112619877.32,5541732.9,324807.11,2331542.53],"type":"bar"},{"marker":{"color":"orange"},"name":"Views","x":["Bowrider","Cabin Boat","Catamaran","Center console boat","Classic","Deck Boat","Fishing Boat","Flybridge","Hardtop","House Boat","Ketch","Launch","Mega Yacht","Motor Yacht","Motorsailer","Offshore Boat","Passenger boat","Pilothouse","Pontoon Boat","RIB","Runabout","Sport Boat","Trawler","Wakeboard/Wakesurf","Water ski","Working Boat"],"y":[53258,162762,4304,38722,51510,30684,34296,130350,69669,26185,97,6476,20128,359018,287,12868,4503,74997,15122,43,15444,257024,75456,22407,2979,6313],"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887 ...

# %% [markdown]
# **Are there shared characteristics among the most viewed boats?**

# %%
boat_sales_clean.head()
# Out:
#              Boat Type          Manufacturer                 Type  Year Built  \
# 0          Motor Yacht  Rigiflex power boats  new boat from stock        2017
# 1  Center console boat     Terhi power boats  new boat from stock        2020
# 2           Sport Boat    Marine power boats  new boat from stock           0
# 3           Sport Boat    Pioner power boats  new boat from stock        2020
# 4         Fishing Boat    Linder power boats  new boat from stock        2019
#
#    Length  Width       Material  Number of views last 7 days Currency  \
# 0    4.00   1.90            GRP                          226      CHF
# 1    4.00   1.50  Thermoplastic                           75      EUR
# 2    3.69   1.42      Aluminium                          124      CHF
# 3    3.00   1.00            GRP                           64      DKK
# 4    3.55   1.46      Aluminium                           58      EUR
#
#    GBP Price       Country              City Other Type
# 0    2969.93  Switzerland       Lake Geneva        None
# 1    3036.30      Germany        Bnningstedt       None
# 2    3355.30  Switzerland    Lake of Zurich        None
# 3    2849.00      Denmark          Svendborg       None
# 4    2957.13      Germany            Bayern        None

# %%
#Grouping the dat by 'Boat Type', 'Manufacturer', 'Type', 'Length', 'Width', 'Year Built', 'Material'
boat_type_group2 = boat_sales_clean.groupby(['Boat Type', 'Manufacturer', 'Type', 'Length', 'Width', 'Year Built', 'Material'], as_index=False)["Number of views last 7 days"].sum()
#Sorting the data by Number of views last 7 days in decending order and getting top ten most viewed boats
boat_type_group2 = boat_type_group2.nlargest(n=10, columns=['Number of views last 7 days']).sort_values(by='Number of views last 7 days', ascending = False)


#creating a treemap that shows the total purchase by pizza size on specific days.
fig5 = px.treemap(boat_type_group2, path=[px.Constant('shared characteristics'),'Boat Type', 'Manufacturer', 'Type', 'Length', 'Width', 'Year Built', 'Material'], color='Boat Type',title = 'Shared Characteristics Among The Top 10 Most Viewed Boats')
fig5.update_traces(marker=dict(cornerradius=50))
fig5.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig5.layout.hovermode= False
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bbb04cf5-b537-44a9-b30f-bbb8a94016b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbb04cf5-b537-44a9-b30f-bbb8a94016b0")) {                    Plotly.newPlot(                        "bbb04cf5-b537-44a9-b30f-bbb8a94016b0",                        [{"branchvalues":"total","customdata":[["Cabin Boat"],["Sport Boat"],["Sport Boat"],["Sport Boat"],["Sport Boat"],["Hardtop"],["Bowrider"],["Hardtop"],["Cabin Boat"],["Motor Yacht"],["Hardtop"],["Sport Boat"],["Cabin Boat"],["Motor Yacht"],["Sport Boat"],["Sport Boat"],["Bowrider"],["Sport Boat"],["Hardtop"],["Cabin Boat"],["Sport Boat"],["Cabin Boat"],["Sport Boat"],["Sport Boat"],["Sport Boat"],["Cabin Boat"],["Motor Yacht"],["Bowrider"],["Hardtop"],["Hardtop"],["Sport Boat"],["Sport Boat"],["Cabin Boat"],["Sport Boat"],["Cabin Boat"],["Sport Boat"],["Motor Yacht"],["Hardtop"],["Bowrider"],["Hardtop"],["Hardtop"],["Hardtop"],["Bowrider"],["Sport Boat"],["Motor Yacht"],["Sport Boat"],["Cabin Boat"],["Sport Boat"],["Sport Boat"],["Cabin Boat"],["Sport Boat"],["Motor Yacht"],["Sport Boat"],["Cabin Boat"],["Hardtop"],["Hardtop"],["Sport Boat"],["Sport Boat"],["Cabin Boat"],["Bowrider"],["Bowrider"],["Cabin Boat"],["Hardtop"],["Motor Yacht"],["Sport Boat"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<br>Boat Type=%{customdata[0]}<extra></extra>","ids":["shared characteristics/Cabin Boat/Draco power boats/Used boat,Unleaded/6.2/2.45/1980/GRP","shared characteristics/Sport Boat/Correct Craft power boats/Used boat,Unleaded/6.4/2.31/2005/GRP","shared characteristics/Sport Boat/Sea Ray power boats/Used boat,Unleaded/6.14/2.34/1993/Plastic","shared characteristics/Sport Boat/Tullio Abbate power boats/Used boat,Unleaded/6.0/2.1/1980/GRP","shared characteristics/Sport Boat/Baha power boats/Used boat,Unleaded/6.8/2.38/1995/GRP","shared characteristics/Hardtop/Princess power boats/Used boat,Diesel/11.12/3.88/1979/GRP","shared characteristics/Bowrider/Windy power boats/Used boat,Diesel/12.35/3.48/2002/GRP","shared characteristics/Hardtop/Pershing power boats/Used boat,Diesel/20.3/5.2/2009/GRP","shared characteristics/Cabin Boat/Viper power boats/Used boat,Unleaded/6.65/2.3/2014/GRP","shared characteristics/Motor Yacht/Bayliner power boats/Used boat,Unleaded/7.7/2.46/1992/Plastic","shared characteristics/Hardtop/Princess power boats/Used boat,Diesel/11.12/3.88/1979","shared characteristics/Sport Boat/Tullio Abbate power boats/Used boat,Unleaded/6.0/2.1/1980","shared characteristics/Cabin Boat/Draco power boats/Used boat,Unleaded/6.2/2.45/1980","shared characteristics/Motor Yacht/Bayliner power boats/Used boat,Unleaded/7.7/2.46/1992","shared characteristics/Sport Boat/Sea Ray power boats/Used boat,Unleaded/6.14/2.34/1993","shared characteristics/Sport Boat/Baha power boats/Used boat,Unleaded/6.8/2.38/1995","shared characteristics/Bowrider/Windy power boats/Used boat,Diesel/12.35/3.48/2002","shared characteristics/Sport Boat/Correct Craft power boats/Used boat,Unleaded/6.4/2.31/2005","shared characteristics/Hardtop/Pershing power boats/Used boat,Diesel/20.3/5.2/2009","shared characteristics/Cabin Boat/Viper power boats/Used boat,Unleaded/6.65/2.3/2014","shared characteristics/Sport Boat/Tullio Abbate power boats/Used boat,Unleaded/6.0/2.1","shared characteristics/Cabin Boat/Viper power boats/Used boat,Unleaded/6.65/2.3","shared characteristics/Sport Boat/Correct Craft power boats/Used boat,Unleaded/6.4/2.31","shared characteristics/Sport Boat/Sea Ray power boats/Used boat,Unleaded/6.14/2.34","shared characteristics/Sport Boat/Baha power boats/Used boat,Unleaded/6.8/2.38","shared characteristics/Cabin Boat/Draco power boats ...
